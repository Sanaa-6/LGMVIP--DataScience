# %% [markdown]
# <a href="https://colab.research.google.com/github/Sanaa-6/LGMVIP--DataScience/blob/main/Task_3_Exploratory_Data_Analysis_on_Dataset_Terrorism.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Exploratory Data Analysis on Dataset - Terrorism**

# %% [markdown]
# As a security/defense analyst, try to find out the hot zone of terrorism. Reading and Analyzing the Dataset:

# %% [markdown]
# **Author Name - Sanjana Patil.**

# %% [markdown]
# Link for the dataset: https://bit.ly/2TK5Xn5

# %% [markdown]
# # **Importing the Dependencies**

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import warnings
warnings.filterwarnings("ignore")
from sklearn.preprocessing import LabelEncoder

# %% [markdown]
# # **Loading the dataset**

# %%
dataset=pd.read_csv('/content/globalterrorismdb_0718dist.csv', encoding = 'ISO-8859-1')

# %%
dataset
# Out:
#             eventid  iyear  imonth  iday approxdate  extended resolution  \
# 0      197000000001   1970       7     2        NaN         0        NaN
# 1      197000000002   1970       0     0        NaN         0        NaN
# 2      197001000001   1970       1     0        NaN         0        NaN
# 3      197001000002   1970       1     0        NaN         0        NaN
# 4      197001000003   1970       1     0        NaN         0        NaN
# ...             ...    ...     ...   ...        ...       ...        ...
# 14254  198108290004   1981       8    29        NaN         0        NaN
# 14255  198108290005   1981       8    29        NaN         0        NaN
# 14256  198108290006   1981       8    29        NaN         0        NaN
# 14257  198108290007   1981       8    29        NaN         0        NaN
# 14258  198108300001   1981       8    30        NaN         0        NaN
#
#        country               country_txt  region  ... addnotes scite1 scite2  \
# 0           58        Dominican Republic       2  ...      NaN    NaN    NaN
# 1          130                    Mexico       1  ...      NaN    NaN    NaN
# 2          160               Philippines       5  ...      NaN    NaN    NaN
# 3           78                    Greece       8  ...      NaN    NaN    NaN
# 4          101                     Japan       4  ...      NaN    NaN    NaN
# ...        ...                       ...     ...  ...      ...    ...    ...
# 14254       97                    Israel      10  ...      NaN    NaN    NaN
# 14255       15                   Austria       8  ...      NaN    NaN    NaN
# 14256       94                      Iran      10  ...      NaN    NaN    NaN
# 14257       94                      Iran      10  ...      NaN    NaN    NaN
# 14258      155  West Bank and Gaza Strip      10  ...      NaN    NaN    NaN
#
#        scite3  dbsource  INT_LOG  INT_IDEO INT_MISC INT_ANY  related
# 0         NaN      PGIS      0.0       0.0      0.0     0.0      NaN
# 1         NaN      PGIS      0.0       1.0      1.0     1.0      NaN
# 2         NaN      PGIS     -9.0      -9.0      1.0     1.0      NaN
# 3         NaN      PGIS     -9.0      -9.0      1.0     1.0      NaN
# 4         NaN      PGIS     -9.0      -9.0      1.0     1.0      NaN
# ...       ...       ...      ...       ...      ...     ...      ...
# 14254     NaN      PGIS      1.0       0.0      0.0     1.0      NaN
# 14255     NaN      PGIS     -9.0      -9.0      0.0    -9.0      NaN
# 14256     NaN      PGIS     -9.0      -9.0      0.0    -9.0      NaN
# 14257     NaN      PGIS     -9.0      -9.0      0.0    -9.0      NaN
# 14258     NaN       NaN      NaN       NaN      NaN     NaN      NaN
#
# [14259 rows x 135 columns]

# %% [markdown]
# ## **Exploratory Data Analysis**

# %%
# printing the first five rows of the dataset
dataset.head()
# Out:
#         eventid  iyear  imonth  iday approxdate  extended resolution  country  \
# 0  197000000001   1970       7     2        NaN         0        NaN       58
# 1  197000000002   1970       0     0        NaN         0        NaN      130
# 2  197001000001   1970       1     0        NaN         0        NaN      160
# 3  197001000002   1970       1     0        NaN         0        NaN       78
# 4  197001000003   1970       1     0        NaN         0        NaN      101
#
#           country_txt  region  ... addnotes scite1 scite2  scite3  dbsource  \
# 0  Dominican Republic       2  ...      NaN    NaN    NaN     NaN      PGIS
# 1              Mexico       1  ...      NaN    NaN    NaN     NaN      PGIS
# 2         Philippines       5  ...      NaN    NaN    NaN     NaN      PGIS
# 3              Greece       8  ...      NaN    NaN    NaN     NaN      PGIS
# 4               Japan       4  ...      NaN    NaN    NaN     NaN      PGIS
#
#    INT_LOG  INT_IDEO INT_MISC INT_ANY  related
# 0      0.0       0.0      0.0     0.0      NaN
# 1      0.0       1.0      1.0     1.0      NaN
# 2     -9.0      -9.0      1.0     1.0      NaN
# 3     -9.0      -9.0      1.0     1.0      NaN
# 4     -9.0      -9.0      1.0     1.0      NaN
#
# [5 rows x 135 columns]

# %%
# printing the last five rows of the dataset
dataset.tail()
# Out:
#             eventid  iyear  imonth  iday approxdate  extended resolution  \
# 14254  198108290004   1981       8    29        NaN         0        NaN
# 14255  198108290005   1981       8    29        NaN         0        NaN
# 14256  198108290006   1981       8    29        NaN         0        NaN
# 14257  198108290007   1981       8    29        NaN         0        NaN
# 14258  198108300001   1981       8    30        NaN         0        NaN
#
#        country               country_txt  region  ... addnotes scite1 scite2  \
# 14254       97                    Israel      10  ...      NaN    NaN    NaN
# 14255       15                   Austria       8  ...      NaN    NaN    NaN
# 14256       94                      Iran      10  ...      NaN    NaN    NaN
# 14257       94                      Iran      10  ...      NaN    NaN    NaN
# 14258      155  West Bank and Gaza Strip      10  ...      NaN    NaN    NaN
#
#        scite3  dbsource  INT_LOG  INT_IDEO INT_MISC INT_ANY  related
# 14254     NaN      PGIS      1.0       0.0      0.0     1.0      NaN
# 14255     NaN      PGIS     -9.0      -9.0      0.0    -9.0      NaN
# 14256     NaN      PGIS     -9.0      -9.0      0.0    -9.0      NaN
# 14257     NaN      PGIS     -9.0      -9.0      0.0    -9.0      NaN
# 14258     NaN       NaN      NaN       NaN      NaN     NaN      NaN
#
# [5 rows x 135 columns]

# %% [markdown]
# # **Printing the shape and features of the dataset**

# %%
# checking the shape 
dataset.shape
# Out:
# (14259, 135)

# %%
dataset.columns
# Out:
# Index(['eventid', 'iyear', 'imonth', 'iday', 'approxdate', 'extended',
#        'resolution', 'country', 'country_txt', 'region',
#        ...
#        'addnotes', 'scite1', 'scite2', 'scite3', 'dbsource', 'INT_LOG',
#        'INT_IDEO', 'INT_MISC', 'INT_ANY', 'related'],
#       dtype='object', length=135)

# %%
for column in dataset.columns:
  print(column)
# Out:
# eventid
# iyear
# imonth
# iday
# approxdate
# extended
# resolution
# country
# country_txt
# region
# region_txt
# provstate
# city
# latitude
# longitude
# specificity
# vicinity
# location
# summary
# crit1
# crit2
# crit3
# doubtterr
# alternative
# alternative_txt
# multiple
# success
# suicide
# attacktype1
# attacktype1_txt
# attacktype2
# attacktype2_txt
# attacktype3
# attacktype3_txt
# targtype1
# targtype1_txt
# targsubtype1
# targsubtype1_txt
# corp1
# target1
# natlty1
# natlty1_txt
# targtype2
# targtype2_txt
# targsubtype2
# targsubtype2_txt
# corp2
# target2
# natlty2
# natlty2_txt
# targtype3
# targtype3_txt
# targsubtype3
# targsubtype3_txt
# corp3
# target3
# natlty3
# natlty3_txt
# gname
# gsubname
# gname2
# gsubname2
# gname3
# gsubname3
# motive
# guncertain1
# guncertain2
# guncertain3
# individual
# nperps
# nperpcap
# claimed
# claimmode
# claimmode_txt
# claim2
# claimmode2
# claimmode2_txt
# claim3
# claimmode3
# claimmode3_txt
# compclaim
# weaptype1
# weaptype1_txt
# weapsubtype1
# weapsubtype1_txt
# weaptype2
# weaptype2_txt
# weapsubtype2
# weapsubtype2_txt
# weaptype3
# weaptype3_txt
# weapsubtype3
# weapsubtype3_txt
# weaptype4
# weaptype4_txt
# weapsubtype4
# weapsubtype4_txt
# weapdetail
# nkill
# nkillus
# nkillter
# nwound
# nwoundus
# nwoundte
# property
# propextent
# propextent_txt
# propvalue
# propcomment
# ishostkid
# nhostkid
# nhostkidus
# nhours
# ndays
# divert
# kidhijcountry
# ransom
# ransomamt
# ransomamtus
# ransompaid
# ransompaidus
# ransomnote
# hostkidoutcome
# hostkidoutcome_txt
# nreleased
# addnotes
# scite1
# scite2
# scite3
# dbsource
# INT_LOG
# INT_IDEO
# INT_MISC
# INT_ANY
# related

# %% [markdown]
# # **Feature Selection**

# %%
data = dataset[["eventid","iyear", "imonth", "iday","gname", "country_txt", "provstate", "region_txt", 
           "longitude", "latitude", "attacktype1_txt", "target1", "nkill", "nwound", 
           "summary", "gname", "targtype1_txt", "weaptype1_txt", "motive"]]

# %%
# printing the first five rows of the dataframe
data.head()
# Out:
#         eventid  iyear  imonth  iday                               gname  \
# 0  197000000001   1970       7     2                              MANO-D
# 1  197000000002   1970       0     0  23rd of September Communist League
# 2  197001000001   1970       1     0                             Unknown
# 3  197001000002   1970       1     0                             Unknown
# 4  197001000003   1970       1     0                             Unknown
#
#           country_txt provstate                   region_txt   longitude  \
# 0  Dominican Republic       NaN  Central America & Caribbean  -69.951164
# 1              Mexico   Federal                North America  -99.086624
# 2         Philippines    Tarlac               Southeast Asia  120.599741
# 3              Greece    Attica               Western Europe   23.762728
# 4               Japan   Fukouka                    East Asia  130.396361
#
#     latitude                 attacktype1_txt                  target1  nkill  \
# 0  18.456792                   Assassination             Julio Guzman    1.0
# 1  19.371887     Hostage Taking (Kidnapping)  Nadine Chaval, daughter    0.0
# 2  15.478598                   Assassination                 Employee    1.0
# 3  37.997490               Bombing/Explosion             U.S. Embassy    NaN
# 4  33.580412  Facility/Infrastructure Attack           U.S. Consulate    NaN
#
#    nwound summary                               gname  \
# 0     0.0     NaN                              MANO-D
# 1     0.0     NaN  23rd of September Communist League
# 2     0.0     NaN                             Unknown
# 3     NaN     NaN                             Unknown
# 4     NaN     NaN                             Unknown
#
#                  targtype1_txt weaptype1_txt motive
# 0  Private Citizens & Property       Unknown    NaN
# 1      Government (Diplomatic)       Unknown    NaN
# 2          Journalists & Media       Unknown    NaN
# 3      Government (Diplomatic)    Explosives    NaN
# 4      Government (Diplomatic)    Incendiary    NaN

# %%
# printing the last five rows of the dataframe
data.tail()
# Out:
#             eventid  iyear  imonth  iday         gname  \
# 14254  198108290004   1981       8    29  Palestinians
# 14255  198108290005   1981       8    29       Unknown
# 14256  198108290006   1981       8    29       Unknown
# 14257  198108290007   1981       8    29       Unknown
# 14258  198108300001   1981       8    30           NaN
#
#                     country_txt  provstate                  region_txt  \
# 14254                    Israel  Jerusalem  Middle East & North Africa
# 14255                   Austria     Vienna              Western Europe
# 14256                      Iran       Fars  Middle East & North Africa
# 14257                      Iran     Tehran  Middle East & North Africa
# 14258  West Bank and Gaza Strip        NaN                   Middle Ea
#
#        longitude   latitude                 attacktype1_txt  \
# 14254  35.203400  31.771599               Bombing/Explosion
# 14255  16.373819  48.208174               Bombing/Explosion
# 14256  52.198101  30.318812  Facility/Infrastructure Attack
# 14257  51.405190  35.724533                         Unknown
# 14258        NaN        NaN                             NaN
#
#                                        target1  nkill  nwound summary  \
# 14254  Army Cooperative Society, Herzel Street    NaN     NaN     NaN
# 14255             Synagogue Seitenstettengasse    2.0    19.0     NaN
# 14256                             3 food shops    NaN     NaN     NaN
# 14257           Revolutionary Committee Office    0.0     4.0     NaN
# 14258                                      NaN    NaN     NaN     NaN
#
#               gname                   targtype1_txt weaptype1_txt motive
# 14254  Palestinians                        Military    Explosives    NaN
# 14255       Unknown  Religious Figures/Institutions    Explosives    NaN
# 14256       Unknown                        Business    Incendiary    NaN
# 14257       Unknown                        Military       Unknown    NaN
# 14258           NaN                             NaN           NaN    NaN

# %% [markdown]
# **Renaming the columns of the dataset**

# %%
#renaming
data.rename(columns={'eventid':'eventNo.','iyear':'Year','imonth':'Month','iday':'Day','gname':'groupname','country_txt':'Country','provstate':'State', 
                    'region_txt':'Region','longitude':'Longitude', 'latitude':'Latitude', 'attacktype1_txt':'AttackType',
                    'target1':'Target','nkill':'Killed','nwound':'Wounded','summary':'Summary','gname':'Group',
                    'targtype1_txt':'Target_type', 'weaptype1_txt':'Weapon_type','motive':'Motive'},inplace=True)

# %%
## printing the first five rows of the dataframe
data.head()
# Out:
#        eventNo.  Year  Month  Day                               Group  \
# 0  197000000001  1970      7    2                              MANO-D
# 1  197000000002  1970      0    0  23rd of September Communist League
# 2  197001000001  1970      1    0                             Unknown
# 3  197001000002  1970      1    0                             Unknown
# 4  197001000003  1970      1    0                             Unknown
#
#               Country    State                       Region   Longitude  \
# 0  Dominican Republic      NaN  Central America & Caribbean  -69.951164
# 1              Mexico  Federal                North America  -99.086624
# 2         Philippines   Tarlac               Southeast Asia  120.599741
# 3              Greece   Attica               Western Europe   23.762728
# 4               Japan  Fukouka                    East Asia  130.396361
#
#     Latitude                      AttackType                   Target  Killed  \
# 0  18.456792                   Assassination             Julio Guzman     1.0
# 1  19.371887     Hostage Taking (Kidnapping)  Nadine Chaval, daughter     0.0
# 2  15.478598                   Assassination                 Employee     1.0
# 3  37.997490               Bombing/Explosion             U.S. Embassy     NaN
# 4  33.580412  Facility/Infrastructure Attack           U.S. Consulate     NaN
#
#    Wounded Summary                               Group  \
# 0      0.0     NaN                              MANO-D
# 1      0.0     NaN  23rd of September Communist League
# 2      0.0     NaN                             Unknown
# 3      NaN     NaN                             Unknown
# 4      NaN     NaN                             Unknown
#
#                    Target_type Weapon_type Motive
# 0  Private Citizens & Property     Unknown    NaN
# 1      Government (Diplomatic)     Unknown    NaN
# 2          Journalists & Media     Unknown    NaN
# 3      Government (Diplomatic)  Explosives    NaN
# 4      Government (Diplomatic)  Incendiary    NaN

# %%
data.shape
# Out:
# (14259, 19)

# %%
#Null value analysis
data.isnull()
# Out:
#        eventNo.   Year  Month    Day  Group  Country  State  Region  \
# 0         False  False  False  False  False    False   True   False
# 1         False  False  False  False  False    False  False   False
# 2         False  False  False  False  False    False  False   False
# 3         False  False  False  False  False    False  False   False
# 4         False  False  False  False  False    False  False   False
# ...         ...    ...    ...    ...    ...      ...    ...     ...
# 14254     False  False  False  False  False    False  False   False
# 14255     False  False  False  False  False    False  False   False
# 14256     False  False  False  False  False    False  False   False
# 14257     False  False  False  False  False    False  False   False
# 14258     False  False  False  False   True    False   True   False
#
#        Longitude  Latitude  AttackType  Target  Killed  Wounded  Summary  \
# 0          False     False       False   False   False    False     True
# 1          False     False       False   False   False    False     True
# 2          False     False       False   False   False    False     True
# 3          False     False       False   False    True     True     True
# 4          False     False       False   False    True     True     True
# ...          ...       ...         ...     ...     ...      ...      ...
# 14254      False     False       False   False    True     True     True
# 14255      False     False       False   False   False    False     True
# 14256      False     False       False   False    True     True     True
# 14257      False     False       False   False   False    False     True
# 14258       True      True        True    True    True     True     True
#
#        Group  Target_type  Weapon_type  Motive
# 0      False        False        False    True
# 1      False        False        False    True
# 2      False        False        False    True
# 3      False        False        False    True
# 4      False        False        False    True
# ...      ...          ...          ...     ...
# 14254  False        False        False    True
# 14255  False        False        False    True
# 14256  False        False        False    True
# 14257  False        False        False    True
# 14258   True         True         True    True
#
# [14259 rows x 19 columns]

# %%
data.isnull().sum()
# Out:
# eventNo.           0
# Year               0
# Month              0
# Day                0
# Group              1
# Country            0
# State             64
# Region             0
# Longitude        487
# Latitude         487
# AttackType         1
# Target           143
# Killed          2084
# Wounded         3467
# Summary        13346
# Group              1
# Target_type        1
# Weapon_type        1
# Motive         13612
# dtype: int64

# %%
#Filling the null value/missing value
data.fillna(method='ffill', inplace=True)

# %%
data.isnull().sum()
# Out:
# eventNo.       0
# Year           0
# Month          0
# Day            0
# Group          0
# Country        0
# State          1
# Region         0
# Longitude      0
# Latitude       0
# AttackType     0
# Target         0
# Killed         0
# Wounded        0
# Summary        5
# Group          0
# Target_type    0
# Weapon_type    0
# Motive         5
# dtype: int64

# %% [markdown]
# # **Displaying the shape and info of the data**

# %%
data.shape
# Out:
# (14259, 19)

# %%
data.describe()
# Out:
#            eventNo.          Year         Month           Day     Longitude  \
# count  1.425900e+04  14259.000000  14259.000000  14259.000000  14259.000000
# mean   1.977436e+11   1977.372537      6.181079     15.198261    -25.701539
# std    3.139999e+08      3.143381      3.360118      8.980147     55.703044
# min    1.970000e+11   1970.000000      0.000000      0.000000   -157.818968
# 25%    1.976020e+11   1976.000000      3.000000      7.000000    -80.273260
# 50%    1.978122e+11   1978.000000      6.000000     15.000000     -5.956210
# 75%    1.980042e+11   1980.000000      9.000000     23.000000     11.346518
# max    1.981083e+11   1986.000000     12.000000     31.000000    172.636225
#
#            Latitude        Killed       Wounded
# count  14259.000000  14259.000000  14259.000000
# mean      29.322902      1.301915      1.310821
# std       22.180499      7.042131      8.189381
# min      -45.867889      0.000000      0.000000
# 25%       13.724167      0.000000      0.000000
# 50%       37.791927      0.000000      0.000000
# 75%       43.643436      1.000000      0.000000
# max       64.837778    422.000000    285.000000

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14259 entries, 0 to 14258
# Data columns (total 19 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   eventNo.     14259 non-null  int64
#  1   Year         14259 non-null  int64
#  2   Month        14259 non-null  int64
#  3   Day          14259 non-null  int64
#  4   Group        14259 non-null  object
#  5   Country      14259 non-null  object
#  6   State        14258 non-null  object
#  7   Region       14259 non-null  object
#  8   Longitude    14259 non-null  float64
#  9   Latitude     14259 non-null  float64
#  10  AttackType   14259 non-null  object
#  11  Target       14259 non-null  object
#  12  Killed       14259 non-null  float64
#  13  Wounded      14259 non-null  float64
#  14  Summary      14254 non-null  object
#  15  Group        14259 non-null  object
#  16  Target_type  14259 non-null  object
#  17  Weapon_type  14259 non-null  object
#  18  Motive       14254 non-null  object
# dtypes: float64(4), int64(4), object(11)
# memory usage: 2.1+ MB

# %% [markdown]
# ## **Correlation and Heatmap**

# %%
data.corr()
# Out:
#            eventNo.      Year     Month       Day  Longitude  Latitude  \
# eventNo.   1.000000  0.999853 -0.075357 -0.008452   0.038793 -0.244394
# Year       0.999853  1.000000 -0.086104 -0.008597   0.039006 -0.243781
# Month     -0.075357 -0.086104  1.000000  0.002492  -0.016256 -0.019193
# Day       -0.008452 -0.008597  0.002492  1.000000   0.013770  0.017647
# Longitude  0.038793  0.039006 -0.016256  0.013770   1.000000  0.343804
# Latitude  -0.244394 -0.243781 -0.019193  0.017647   0.343804  1.000000
# Killed     0.076385  0.076334 -0.003265 -0.005300  -0.020030 -0.053297
# Wounded    0.012285  0.012252  0.001385 -0.000485   0.089837  0.022642
#
#              Killed   Wounded
# eventNo.   0.076385  0.012285
# Year       0.076334  0.012252
# Month     -0.003265  0.001385
# Day       -0.005300 -0.000485
# Longitude -0.020030  0.089837
# Latitude  -0.053297  0.022642
# Killed     1.000000  0.131794
# Wounded    0.131794  1.000000

# %%
plt.figure(figsize=(10,5))
sns.heatmap(data.corr(), annot=True)
plt.show()

# %% [markdown]
# # **number of unique values**

# %%
data.nunique()
# Out:
# eventNo.       14259
# Year              13
# Month             13
# Day               32
# Group            856
# Country          121
# State            700
# Region            12
# Longitude       2627
# Latitude        2615
# AttackType         9
# Target         10439
# Killed            61
# Wounded           75
# Summary          878
# Group            856
# Target_type       22
# Weapon_type       11
# Motive           290
# dtype: int64

# %% [markdown]
# # **Data Visualizations:**

# %%
plt.subplots(figsize=(15,6))
sns.barplot(data['Country'].value_counts()[:20].index,data['Country'].value_counts()[:20].values,palette = 'dark')
plt.title('Top 20 Countries that are Affected')
plt.xlabel('Countries')
plt.ylabel('Count')
plt.xticks(rotation= 90)
plt.show()

# %%
x_year = data['Year'].unique()
y_count_years = data['Year'].value_counts(dropna = False).sort_index()
plt.figure(figsize = (18,8))
sns.barplot(x = x_year, y = y_count_years, palette = 'rocket_r')
plt.xticks(rotation = 45)
plt.xlabel('Attack Year')
plt.ylabel('Number of Attacks in each year')
plt.title('Number of attacks year wise')
plt.show()

# %%
plt.subplots(figsize=(12,6))
sns.barplot(data['Region'].value_counts().index,data['Region'].value_counts().values)
plt.title('Top Regions that are Affected')
plt.xlabel('Regions')
plt.ylabel('Count')
plt.xticks(rotation= 90)
plt.show()

# %%
plt.subplots(figsize=(15,6))
sns.barplot(data['Country'].value_counts()[:15].index,data['Country'].value_counts()[:15].values,palette = 'viridis')
plt.title('Top Countries Affected')
plt.xlabel('Countries')
plt.ylabel('Count')
plt.xticks(rotation= 90)
plt.show()

# %%
plt.subplots(figsize=(20,6))
sns.barplot(data['State'].value_counts()[:25].index,data['State'].value_counts()[:25].values,palette='YlOrBr_r')
plt.title('Top States that are Affected')
plt.xlabel('States')
plt.ylabel('Count')
plt.xticks(rotation= 90)
plt.show()

# %%
plt.figure(figsize=(12,6))
sns.barplot(x=data['AttackType'].value_counts().index,y = data['AttackType'].value_counts().values, palette = 'dark')
plt.title('common Attack Type')
plt.xlabel('Count')
plt.xticks(rotation= 90)
plt.ylabel('Attack Type')
plt.show()

# %%
Death_each_year = data.groupby(['Year'], dropna = False)['Killed'].sum() 
fig=plt.figure(figsize=(20,7))
Death_each_year.plot(kind = 'bar', colormap = "Set2")
plt.xlabel("Years", fontsize = 12)
plt.ylabel("Number of deaths",fontsize = 12)
plt.xticks(rotation = 90)
plt.title("Number of Deaths each year")
plt.show()

# %%
fig=plt.figure(figsize=(17,7))
sns.set_style("darkgrid")
sns.kdeplot(data['Year'], hue = data['Region'])
plt.xlabel("Years")
plt.ylabel("Number of attacks")
plt.title("Number of Terrorist Attacks by Region in each year")
# Out:
# Text(0.5, 1.0, 'Number of Terrorist Attacks by Region in each year')

# %% [markdown]
# # **Thank You.**
